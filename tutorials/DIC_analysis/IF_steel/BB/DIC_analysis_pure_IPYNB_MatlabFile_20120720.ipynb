# %% [markdown]
# # Dependencies

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['norm', 'axes', 'f', 'std']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
from scipy.io import loadmat
from MP import progress_bar
from glob import glob
import pandas as pd
import time,os
from matplotlib import gridspec
gs=gridspec.GridSpec
uet=progress_bar.update_elapsed_time

from MP.lib import mpl_lib
from MP.lib.mpl_lib import rm_all_lab as ral
from MP.lib.mpl_lib import tune_xy_lim as txl
from matplotlib.colors import LogNorm

from MP.mat import mech

# %% [markdown]
# - Current work direction

# %%
pwd
# Out:
# u'/Users/yj/repo/FLD_DIC_XRAY/tutorials/DIC_analysis/IF_steel/BB'

# %% [markdown]
# - Available files

# %%
ls -l /Users/yj/Documents/ExpDat/IFSteel/Marciniak-X-ray-IF/BB/20120720/DIC
# Out:
# total 4399784
# -rw-r--r--  1 yj  admin      324 Nov  2 18:24 DIC_results.txt
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0001_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0002_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0003_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0004_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0005_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0006_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0007_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0008_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0009_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0010_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0011_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0012_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0013_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0014_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0015_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0016_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0017_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0018_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0019_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0020_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0021_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0022_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0023_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0024_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0025_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0026_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0027_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0028_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0029_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0030_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0031_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0032_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0033_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0034_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0035_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0036_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0037_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0038_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0039_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0040_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0041_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0042_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0043_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0044_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0045_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0046_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0047_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0048_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0049_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0050_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0051_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0052_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0053_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0054_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0055_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0056_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0057_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0058_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0059_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0060_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0061_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0062_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0063_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0064_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0065_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0066_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0067_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0068_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0069_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0070_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0071_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0072_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0073_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0074_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0075_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0076_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0077_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0078_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0079_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0080_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0081_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0082_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0083_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0084_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0085_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0086_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0087_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0088_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0089_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0090_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0091_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0092_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0093_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0094_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0095_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0096_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0097_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0098_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0099_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0100_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0101_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0102_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0103_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0104_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0105_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0106_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0107_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0108_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0109_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0110_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0111_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0112_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0113_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0114_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0115_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0116_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0117_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0118_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0119_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0120_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0121_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0122_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0123_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0124_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0125_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0126_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0127_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0128_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0129_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0130_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0131_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0132_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0133_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0134_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0135_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0136_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0137_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0138_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0139_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0140_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0141_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0142_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0143_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0144_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0145_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0146_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0147_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0148_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0149_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0150_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0151_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0152_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0153_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0154_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0155_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0156_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0157_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0158_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0159_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0160_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0161_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0162_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0163_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0164_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0165_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0166_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0167_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0168_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0169_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0170_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0171_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0172_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0173_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0174_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0175_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0176_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0177_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0178_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0179_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0180_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0181_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0182_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0183_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0184_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0185_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0186_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0187_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0188_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0189_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0190_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0191_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0192_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0193_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0194_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0195_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0196_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0197_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0198_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0199_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0200_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0201_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0202_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0203_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0204_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0205_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0206_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0207_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0208_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0209_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0210_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0211_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0212_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0213_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0214_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0215_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0216_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0217_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0218_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0219_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0220_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0221_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0222_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0223_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0224_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0225_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0226_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0227_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0228_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0229_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0230_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0231_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0232_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0233_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0234_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0235_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0236_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0237_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0238_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0239_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0240_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0241_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0242_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0243_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0244_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0245_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0246_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0247_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0248_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0249_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0250_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0251_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0252_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0253_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0254_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0255_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0256_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0257_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0258_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0259_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0260_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0261_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0262_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0263_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0264_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0265_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0266_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0267_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0268_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0269_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0270_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0271_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0272_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0273_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0274_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0275_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0276_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0277_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0278_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0279_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0280_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0281_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0282_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0283_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0284_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0285_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0286_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0287_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0288_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0289_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0290_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0291_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0292_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0293_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0294_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0295_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0296_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0297_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0298_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0299_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0300_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0301_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0302_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0303_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0304_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0305_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0306_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0307_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0308_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0309_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0310_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0311_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0312_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0313_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0314_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0315_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0316_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0317_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0318_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0319_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0320_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0321_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0322_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0323_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0324_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0325_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0326_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0327_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0328_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0329_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0330_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0331_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0332_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0333_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0334_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0335_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0336_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0337_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0338_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0339_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0340_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0341_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0342_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0343_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0344_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0345_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0346_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0347_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0348_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0349_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0350_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0351_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0352_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0353_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0354_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0355_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0356_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0357_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0358_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0359_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0360_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0361_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0362_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0363_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0364_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0365_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0366_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0367_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0368_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0369_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0370_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0371_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0372_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0373_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0374_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0375_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0376_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0377_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0378_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0379_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0380_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0381_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0382_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0383_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0384_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0385_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0386_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0387_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0388_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0389_0.mat
# -rw-r--r--  1 yj  admin  3909037 Mar 30  2015 data-0390_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0391_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0392_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0393_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0394_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0395_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0396_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0397_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0398_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0399_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0400_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0401_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0402_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0403_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0404_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0405_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0406_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0407_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0408_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0409_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0410_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0411_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0412_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0413_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0414_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0415_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0416_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0417_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0418_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0419_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0420_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0421_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0422_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0423_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0424_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0425_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0426_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0427_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0428_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0429_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0430_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0431_0.mat
# -rw-r--r--  1 yj  admin  5330529 Mar 30  2015 data-0432_0.mat

# %% [markdown]
# - Pick a file name ( each file corresponds to single snapshot)

# %%
fn_start='/Users/yj/Documents/ExpDat/IFSteel/Marciniak-X-ray-IF/BB/20120720/DIC/data-0???_0.mat'
fns=glob(fn_start)
for fn in fns:
    #print fn
    if not(os.path.isfile(fn)):
        raise IOError, '%s is not loadable'%fn

# %% [markdown]
# - Load the file and measure the file loading time

# %%
t0=time.time()
dat_raw=[]
dic_ind=[]
for fn in fns:
    dum=os.path.split(fn)[-1].split('.mat')[0][::-1]
    dum = dum[:6][::-1]
    ind=int(dum[:4:])
    dic_ind.append(ind)
    dat_dict=loadmat(fn)
    dat_raw.append(dat_dict)
    uet(time.time()-t0,head='loading time:')
# Out:
# loading time::          13 [sec]

# %%
# print dic_ind

# %% [markdown]
# - Variables available in each file

# %%
print dat_raw[0].keys()
# Out:
# ['q_ref', 'dV_dt', 'X', 'dExx_dt', 'dEyy_dt', 'eyy', 'r_ref', 'e_vonmises', 'e3_dot', 'U', 'W', 'V', 'Y', 'dU_dt', 'Z', 'e1', 'e3', 'e2', 'dExy_dt', 'q', 'r', 'u', 'exx', 'v', 'y', 'x', 'dW_dt', 'sigma', 'gamma', 'exy']

# %%
nstp = len(dat_raw)
nx,ny = dat_raw[-1]['sigma'].shape
print 'Total number of steps (# of DIC snapshots):', nstp
print '2D resolution (nx,ny):', nx,ny,'nx*ny:',nx*ny
# Out:
# Total number of steps (# of DIC snapshots): 432
# 2D resolution (nx,ny): 189 235 nx*ny: 44415

# %% [markdown]
# # Comparison between unfiltered raw data and data filtered by $\sigma$

# %%
fig=plt.figure(121,figsize=(8,4))
ax1=fig.add_subplot(121)
ax2=fig.add_subplot(122)
ax1.scatter(dat_raw[-1]['X'],dat_raw[-1]['Y'],marker='.',s=0.05)
ax1.set_xlim(-25,25);ax1.set_ylim(-25,25)
ax1.set_aspect('equal');ax1.set_title('Unfiltered')

ax2.scatter(dat_raw[-1]['X'][dat_raw[-1]['sigma']>0],dat_raw[-1]['Y'][dat_raw[-1]['sigma']>0],marker='.',s=0.05)
ax2.set_xlim(-25,25);ax2.set_ylim(-25,25)
ax2.set_aspect('equal');ax2.set_title(r'Filtered by $\sigma>0$')

# %% [markdown]
# # Define necessary functions

# %%
"""
Find minimum or maximum discarding +- inp and nan
"""
def find_mx(a):
    mx=None
    for i in xrange(len(a)):
        if ((a[i]>mx and a[i]!=np.inf) or mx==None) and not(np.isnan(a[i])): mx=a[i]
    return mx

def find_mn(a):
    mn=None
    for i in xrange(len(a)):
        if ((a[i]<mn and a[i]!=-np.inf) or mn==None) and not(np.isnan(a[i])): mn=a[i]
    return mn

def find_mxmn(*args):
    """
    Return max and min
    """
    maxs, mns=[], []
    for a in args:
        mns.append(find_mn(a))
        mxs.append(find_mx(a))
    return mxs, mns

## Contruct a normalized spectrum of color
def make_cb(dat,mn=None,mx=None,log=False):
    """
    Arguments
    =========
    dat
    mn  = None
    mx  = None
    log = False (If True, use LogNorm)
    """
    array = dat.flatten()
    if mn==None: mn = find_mn(array) 
    if mx==None: mx = find_mx(array)
    if log: norm=LogNorm(vmin=mn,vmax=mx)
    else:   norm=mpl.colors.Normalize(vmin=mn,vmax=mx)
    cmap,m = mpl_lib.norm_cmap(mn=mn,mx=mx,cm_name='jet')
    return cmap, norm, m

# %% [markdown]
# - Data masking bases on $\sigma$ values - those elements with $\sigma>0.$

# %%
#np.maskdat_raw[0]['q_ref']
t0=time.time()
iplot=False

for istp in xrange(nstp):
    dum=dat_raw[istp]['sigma'][dat_raw[istp]['sigma']>0]
    if iplot: plot(dum.flatten(),'x')
    if iplot: uet(time.time()-t0,head='plotting time:')
uet(time.time()-t0,head='Total time elapsed')
# Out:
# Total time elapsed:         291 [ ms]

# %% [markdown]
# - Test dat_mask can easily mask unwanted data based on its 'key' from the dictionary raw data "dat_raw" array.

# %%
def dat_mask(dat_raw,istp,*keys):
    """
    From dat_raw, mask the data
    that have its corresponding 'sigma' value 
    lower than zero.
    
    Also, return masked data for the given step.
    """
    d=[]
    k=0
    for key in keys:
        # if k==0:print np.array(dat_raw[istp][key]).shape
        array = dat_raw[istp][key]
        sigma = dat_raw[istp]['sigma']
        array = array[sigma>0]
        d.append(array)        
        k=k+1
    return d

## --
key='exx'
#key='dExx_dt'
#key='e3'
print 'key:"%s"'%key,'\n-----------'
for istp in xrange(nstp):
    x, y, z = dat_mask(dat_raw,istp,'X','Y',key)
    mx, mn  = find_mx(z), find_mn(z)
    #if istp==0: print '%5s %5s'%('min','max')
    #print '%5.3f %5.3f'%(mn, mx)

cmap, norm, m = make_cb(z,mn=mn,mx=mx)
C=m.to_rgba(z)
scatter(x,y,color=C,marker='.',s=0.3)
plt.gca().set_aspect('equal')
# Out:
# key:"exx"
# -----------

# %% [markdown]
# # PLOT XY(Z)

# %%
istp=-70
keys = 'e_vonmises'
X,Y,Z = dat_mask(dat_raw, istp, 'X','Y',key)  ## premasked array by 'sigma'
mn,mx=find_mn(Z),find_mx(Z)
cmap,norm,m = make_cb(dat=Z,mn=mn,mx=mx)

nx,= X.shape
print 'nx',nx
cs=[];X_=[];Y_=[];

c = m.to_rgba(Z)
plt.scatter(X,Y,marker='.',color=c,s=0.5)#,s=0.05)
plt.gca().set_xlim(-35,35); plt.gca().set_ylim(-35,35)
plt.gca().set_aspect('equal')
# Out:
# nx 30796

# %%
"""
Keys in the dictionary file:
----------------------------
'q_ref', 'dV_dt', 'X', 'dExx_dt', 'dEyy_dt', 'eyy', 'r_ref', 'e_vonmises', 'e3_dot', 'U', 'W', 'V', 'Y', 'dU_dt',
'Z', 'e1', 'e3', 'e2', 'dExy_dt', 'q', 'r', 'u', 'exx', 'v', 'y', 'x', 'dW_dt', 'sigma', 'gamma', 'exy'
"""
t0=time.time()
key = 'e_vonmises'

nc=int(sqrt(nstp))+1
nr=nstp/nc; nr = nr + 1
print nc,nr

if nc*nr<nstp: raise IOError, 'Insufficient cells'
g=gs(nc*10,(nr+1)*10,hspace=0,wspace=0)

ux=2;uy=2

## Switch for plotting
### ---------------------------------------------------------------
iplot=False
### ---------------------------------------------------------------
if iplot: fig=plt.figure(figsize=((nr+1)*ux,nc*uy))

mns=[];mxs=[]
for istp in xrange(nstp):
    Z, = dat_mask(dat_raw,istp,key)
    mn, mx = find_mn(Z),find_mx(Z)
    mns.append(mn); mxs.append(mx)
    uet(time.time()-t0,head='Elapsed time for finding max and min:')
mn,mx = find_mn(mns), find_mx(mxs)
print
print 'minimum and maximum',mn, mx

if iplot:
    norm = mpl.colors.Normalize(vmin=mn,vmax=mx)
    cmap, m = mpl_lib.norm_cmap(mn=mn,mx=mx)




k = 0; axes = []
t0=time.time()
for i in xrange(nc):
    for j in xrange(nr):
        if iplot:
            ax=fig.add_subplot(g[i*10:(i+1)*10,j*10:(j+1)*10])
            ax.set_aspect('equal')
            ax.minorticks_on()
            ax.tick_params(axis='both', which='major', labelsize=15)
            ax.tick_params(axis='both', which='minor', labelsize=8)

        x,y,z=dat_mask(dat_raw,k,'X','Y',key)
        if iplot:
            cs=m.to_rgba(z)
            ax.scatter(x,y,marker='.',color=cs,s=0.02)
            ax.set_xlim(-35,35);ax.set_ylim(-35,35)
            ax.locator_params(nbins=4)
            ax.text(x=0.8,y=0.9,s='# %i'%k,verticalalignment='center',
                    horizontalalignment='center',
                    fontsize=12,transform=ax.transAxes)
        k=k+1
        if i==nc-1 and j==0:
            if iplot:
                ax.set_xlabel('X [mm]',dict(fontsize=15))
                ax.set_ylabel('Y [mm]',dict(fontsize=15))
        else: 
            if iplot:
                axes.append(ax)
        if iplot: uet(time.time()-t0,head='Elapsed time for plotting:')
        else: uet(time.time()-t0,head='Elapsed time for data masking')
        if k>=nstp: break
    if k>=nstp: break

if iplot:
    txl(fig.axes)        
    ral(axes)

    axcb=fig.add_subplot(g[(nc-1)*10:(nc)*10,(nr)*10+1:(nr)*10+2])
    mpl_lib.add_cb(ax=axcb,cmap=cmap, filled=True,
                   format='%5.3f',norm=norm,
                   ylab=r'%s '%key)

uet(time.time()-t0,head='Elapsed time:')
print '*'*10, 'completed', '*'*10
# Out:
# 21 21
# Elapsed time for finding max and min::          14 [sec]
# minimum and maximum 1.26465e-18 1.57351
# Elapsed time::           2 [sec]********** completed **********

# %% [markdown]
# ## -- As a first approximation, get an average with an small area

# %% [markdown]
# - Reduce data set by area

# %%
def r_area(x,y,rad,x0,y0,*args):
    """
    Reduce the data by its radius
    """
    x,y = x-x0,y-y0
    r = np.sqrt(x**2+y**2)
    zs=[]
    for arg in args:
        zs.append(arg[r<rad])
    return zs

def rr(x,y,rad,x0,y0,p,*args):
    #print len(x) ,' ->',
    zs=r_area(x,y,rad,x0,y0,*args)
    #print len(zs[0]), '->',
    
    if p<0: return zs
    elif p>0 and p<1: 
        #print len(zs[0])
        n = int(len(zs[0])*p)
        #print n
    elif p==1:
        return zs

    slc = random.choice(len(zs[0]),n)
    Z=[]
    for i in range(len(zs)):
        Z.append(zs[i][slc])
    return Z

def stat(dat):
    return np.average(dat), np.std(dat)
    
## application
key = 'e_vonmises'
x_,y_,z_=dat_mask(dat_raw,0,'X','Y',key)

## masking by 'area' and extract from only a portion of total data
fig=plt.figure(figsize=(11,11))
ax5=fig.add_subplot(322)
ax1=fig.add_subplot(323)
ax2=fig.add_subplot(324)
ax3=fig.add_subplot(325)
ax4=fig.add_subplot(326)

## for BB 20120720
x0=-6.0; y0=0.2;
rad_washer=16.
rad=8.

x,y,z = rr(x_,y_,30,x0,y0,1,x_,y_,z_)
ax1.scatter(x,y,marker='.',c='red')
x,y,z = rr(x_,y_,30,x0,y0,0.01,x_,y_,z_)
ax2.scatter(x,y,marker='x',c='blue')
x,y,z = rr(x_,y_,30,x0,y0,0.05,x_,y_,z_)
ax3.scatter(x,y,marker='+',c='yellow')
x,y,z = rr(x_,y_,40,x0,y0,0.05,x_,y_,z_)
ax4.scatter(x,y,marker='o',c='magenta',s=0.04)

## Trace of window of the washer
thw=np.linspace(-pi,pi)
xw=np.cos(thw)*rad_washer+x0
yw=np.sin(thw)*rad_washer+y0
xa=np.cos(thw)*rad+x0
ya=np.sin(thw)*rad+y0

ax1.plot(x0,y0,'ro')
ax1.plot(xw,yw,'w--')
ax1.plot(xa,ya,'w-')

for ax in fig.axes[1:]:
    ax.plot(x0,y0,'ko')
    ax.plot(xw,yw,'k--')
    ax.plot(xa,ya,'k-')
for ax in fig.axes:
    ax.set_aspect('equal')
plt.tight_layout()

# %%
fig=plt.figure(figsize=(3.5,3.5))
ax1=fig.add_subplot(121)
#ax2=fig.add_subplot(122)

path=os.path.split(fn_start)[0]
fn=os.path.join(path,'DIC_results.txt')
print fn
f=open(fn,'w')

keys=['e1','e2','exx','eyy','exy','sigma']
evm = []
for istp in xrange(nstp):
    if istp==0: 
        f.write('%4s '%'DIC')
        for key in keys:
            f.write('%10s_A %10s_E '%(key,key))
        f.write('\n')
    f.write('%4.4i '%dic_ind[istp])
    for key in keys:
        x, y, z= dat_mask(dat_raw,istp,'X','Y',key)
        zr = rr(x,y,rad,x0,y0,-1,z)
        avg,std= stat(zr)
        f.write(('%+11.5e '*2)%(avg, std))
    f.write('\n')
f.close()
st=os.popen('head -n 3 %s'%fn).read()
print st

dat=np.loadtxt(fn,skiprows=1).T
exx_A, exx_E, eyy_A, eyy_E=dat[5],dat[6],dat[7],dat[8]
nstp=1
ax1.errorbar(exx_A[::nstp], eyy_A[::nstp], xerr = exx_E[::nstp], yerr=eyy_E[::nstp])
# Out:
# /Users/yj/Documents/ExpDat/IFSteel/Marciniak-X-ray-IF/BB/20120720/DIC/DIC_results.txt
#  DIC         e1_A         e1_E         e2_A         e2_E        exx_A        exx_E        eyy_A        eyy_E        exy_A        exy_E      sigma_A      sigma_E
# 0001 -7.97818e-18 +1.68503e-17 -3.31404e-17 +1.53565e-17 -2.33373e-17 +1.82071e-17 -1.77814e-17 +1.78779e-17 +7.46090e-20 +9.21317e-18 +1.36113e-02 +1.70713e-03
# 0002 +1.07130e-03 +1.01021e-03 -8.29859e-04 +8.12536e-04 +2.27813e-04 +1.25974e-03 +1.36315e-05 +6.29254e-04 -1.10146e-05 +8.60775e-04 +1.24587e-02 +1.70598e-03
# <Container object of 3 artists>
