# %% [markdown]
# # Dependencies

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy.io import loadmat
from MP import progress_bar
from glob import glob
import pandas as pd
import time,os
from matplotlib import gridspec
gs=gridspec.GridSpec
uet=progress_bar.update_elapsed_time

from MP.lib import mpl_lib
from MP.lib.mpl_lib import rm_all_lab as ral
from MP.lib.mpl_lib import tune_xy_lim as txl
from matplotlib.colors import LogNorm

from MP.mat import mech

# %% [markdown]
# - Current work direction

# %%
pwd
# Out:
# u'/Users/yj/repo/FLD_DIC_XRAY/tutorials/DIC_analysis/IF_steel/BB'

# %% [markdown]
# - Available files

# %%
ls -l /Users/yj/Documents/ExpDat/IFSteel/Marciniak-X-ray-IF/BB/20141029/DIC
# Out:
# total 2039872
# -rw-r--r--  1 yj  admin    31050 Sep  9 12:12 DIC_results.txt
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0000_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0001_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0002_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0003_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0004_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0005_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0006_0.mat*
# -rwxr-xr-x  1 yj  admin  3425917 Mar 30 14:55 IFsteel_BB-0007_0.mat*
# -rwxr-xr-x  1 yj  admin  3425917 Mar 30 14:55 IFsteel_BB-0008_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0009_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0010_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0011_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0012_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0013_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0014_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0015_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0016_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0017_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0018_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0019_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0020_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0021_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0022_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0023_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0024_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0025_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0026_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0027_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0028_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0029_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0030_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0031_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0032_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0033_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0034_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0035_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0036_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0037_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0038_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0039_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0040_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0041_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0042_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0043_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0044_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0045_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0046_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0047_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0048_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0049_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0050_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0051_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0052_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0053_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0054_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0055_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0056_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0057_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0058_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0059_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0060_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0061_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0062_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0063_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0064_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0065_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0066_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0067_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0068_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0069_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0070_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0071_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0072_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0073_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0074_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0075_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0076_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0077_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0078_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0079_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0080_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0081_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0082_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0083_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0084_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0085_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0086_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0087_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0088_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0089_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0090_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0091_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0092_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0093_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0094_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0095_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0096_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0097_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0098_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0099_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0100_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0101_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0102_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0103_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0104_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0105_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0106_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0107_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0108_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0109_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0110_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0111_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0112_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0113_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0114_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0115_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0116_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0117_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0118_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0119_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0120_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0121_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0122_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0123_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0124_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0125_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0126_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0127_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0128_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0129_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0130_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0131_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0132_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0133_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0134_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0135_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0136_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0137_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0138_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0139_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0140_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0141_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0142_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0143_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0144_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0145_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0146_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0147_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0148_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0149_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0150_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0151_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0152_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0153_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0154_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0155_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0156_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0157_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0158_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0159_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0160_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0161_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0162_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0163_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0164_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0165_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0166_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0167_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0168_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0169_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0170_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0171_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0172_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0173_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0174_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0175_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0176_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0177_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0178_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0179_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0180_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0181_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0182_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0183_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0184_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0185_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0186_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0187_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0188_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0189_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0190_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0191_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0192_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0193_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0194_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0195_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0196_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0197_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0198_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0199_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0200_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0201_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0202_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0203_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0204_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0205_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0206_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0207_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0208_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0209_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0210_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0211_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0212_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0213_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0214_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0215_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0216_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0217_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0218_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0219_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0220_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0221_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0222_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0223_0.mat*

# %% [markdown]
# - Pick a file name ( each file corresponds to single snapshot)

# %%
fn_start='/Users/yj/Documents/ExpDat/IFSteel/Marciniak-X-ray-IF/BB/20141029/DIC/IFsteel_BB-0???_0.mat'
fns=glob(fn_start)
for fn in fns:
    # print fn
    if not(os.path.isfile(fn)):
        raise IOError, '%s is not loadable'%fn

# %% [markdown]
# - Load the file and measure the file loading time

# %%
t0=time.time()
dat_raw=[]
dic_ind=[]
for i in xrange(len(fns)):
    fn =fns[i]
    dum=os.path.split(fn)[-1].split('.mat')[0][::-1]
    dum = dum[:6][::-1]
    ind=int(dum[:4:])
    # print fn,ind
    dic_ind.append(ind)
    dat_dict=loadmat(fn)
    dat_raw.append(dat_dict)
    if mod(i,10)==0: uet(time.time()-t0,head='loading time:')
# Out:
# loading time::   9 [sec]

# %% [markdown]
# - Variables available in each file

# %%
# print dat_raw[0].keys()

# %%
nstp = len(dat_raw)
nx,ny = dat_raw[-1]['sigma'].shape
print 'Total number of steps (# of DIC snapshots):', nstp
print '2D resolution (nx,ny):', nx,ny,'nx*ny:',nx*ny
# Out:
# Total number of steps (# of DIC snapshots): 224
# 2D resolution (nx,ny): 173 225 nx*ny: 38925

# %% [markdown]
# # Comparison between unfiltered raw data and data filtered by $\sigma$

# %%
fig=plt.figure(121,figsize=(8,4))
ax1=fig.add_subplot(121)
ax2=fig.add_subplot(122)
ax1.scatter(dat_raw[-1]['X'],dat_raw[-1]['Y'],marker='.',s=0.05)
ax1.set_xlim(-25,25);ax1.set_ylim(-25,25)
ax1.set_aspect('equal');ax1.set_title('Unfiltered')

ax2.scatter(dat_raw[-1]['X'][dat_raw[-1]['sigma']>0],dat_raw[-1]['Y'][dat_raw[-1]['sigma']>0],marker='.',s=0.05)
ax2.set_xlim(-25,25);ax2.set_ylim(-25,25)
ax2.set_aspect('equal');ax2.set_title(r'Filtered by $\sigma>0$')

# %% [markdown]
# # Define necessary functions

# %%
"""
Find minimum or maximum discarding +- inp and nan
"""
def find_mx(a):
    mx=None
    for i in xrange(len(a)):
        if ((a[i]>mx and a[i]!=np.inf) or mx==None) and not(np.isnan(a[i])): mx=a[i]
    return mx

def find_mn(a):
    mn=None
    for i in xrange(len(a)):
        if ((a[i]<mn and a[i]!=-np.inf) or mn==None) and not(np.isnan(a[i])): mn=a[i]
    return mn

def find_mxmn(*args):
    """
    Return max and min
    """
    maxs, mns=[], []
    for a in args:
        mns.append(find_mn(a))
        mxs.append(find_mx(a))
    return mxs, mns

## Contruct a normalized spectrum of color
def make_cb(dat,mn=None,mx=None,log=False):
    """
    Arguments
    =========
    dat
    mn  = None
    mx  = None
    log = False (If True, use LogNorm)
    """
    array = dat.flatten()
    if mn==None: mn = find_mn(array) 
    if mx==None: mx = find_mx(array)
    if log: norm=LogNorm(vmin=mn,vmax=mx)
    else:   norm=mpl.colors.Normalize(vmin=mn,vmax=mx)
    cmap,m = mpl_lib.norm_cmap(mn=mn,mx=mx,cm_name='jet')
    return cmap, norm, m

# %% [markdown]
# - Data masking bases on $\sigma$ values - those elements with $\sigma>0.$

# %%
#np.maskdat_raw[0]['q_ref']
t0=time.time()
iplot=False

for istp in xrange(nstp):
    dum=dat_raw[istp]['sigma'][dat_raw[istp]['sigma']>0]
    if iplot: plot(dum.flatten(),'x')
    if iplot: uet(time.time()-t0,head='plotting time:')
uet(time.time()-t0,head='Total time elapsed')
# Out:
# Total time elapsed: 109 [ ms]

# %% [markdown]
# - Test dat_mask can easily mask unwanted data based on its 'key' from the dictionary raw data "dat_raw" array.

# %%
def dat_mask(dat_raw,istp,*keys):
    """
    From dat_raw, mask the data
    that have its corresponding 'sigma' value 
    lower than zero.
    
    Also, return masked data for the given step.
    """
    d=[]
    k=0
    for key in keys:
        # if k==0:print np.array(dat_raw[istp][key]).shape
        array = dat_raw[istp][key]
        sigma = dat_raw[istp]['sigma']
        array = array[sigma>0]
        d.append(array)        
        k=k+1
    return d


## --
key='exx'
#key='dExx_dt'
#key='e3'
print 'key:"%s"'%key,'\n-----------'
for istp in xrange(nstp):
    x, y, z = dat_mask(dat_raw,istp,'X','Y',key)
    mx, mn  = find_mx(z), find_mn(z)
    #if istp==0: print '%5s %5s'%('min','max')
    #print '%5.3f %5.3f'%(mn, mx)

cmap, norm, m = make_cb(z,mn=mn,mx=mx)
C=m.to_rgba(z)
scatter(x,y,color=C,marker='.',s=0.3)
plt.gca().set_aspect('equal')
# Out:
# key:"exx"
# -----------

# %% [markdown]
# # PLOT XY(Z)

# %%
istp=-1
keys = 'e_vonmises'
X,Y,Z = dat_mask(dat_raw, istp, 'X','Y',key)  ## premasked array by 'sigma'
mn,mx=find_mn(Z),find_mx(Z)
cmap,norm,m = make_cb(dat=Z,mn=mn,mx=mx)

nx,= X.shape
print 'nx',nx
cs=[];X_=[];Y_=[];

c = m.to_rgba(Z)
plt.scatter(X,Y,marker='.',color=c,s=0.5)#,s=0.05)
plt.gca().set_xlim(-35,35); plt.gca().set_ylim(-35,35)
plt.gca().set_aspect('equal')
# Out:
# nx 24644

# %%
"""
Keys in the dictionary file:
----------------------------
'q_ref', 'dV_dt', 'X', 'dExx_dt', 'dEyy_dt', 'eyy', 'r_ref', 'e_vonmises', 'e3_dot', 'U', 'W', 'V', 'Y', 'dU_dt',
'Z', 'e1', 'e3', 'e2', 'dExy_dt', 'q', 'r', 'u', 'exx', 'v', 'y', 'x', 'dW_dt', 'sigma', 'gamma', 'exy'
"""
t0=time.time()
key = 'e_vonmises'

nc=int(sqrt(nstp))+1
nr=nstp/nc; nr = nr + 1
print nc,nr

if nc*nr<nstp: raise IOError, 'Insufficient cells'
g=gs(nc*10,(nr+1)*10,hspace=0,wspace=0)

ux=2;uy=2

## Switch for plotting
### ---------------------------------------------------------------
iplot=False
### ---------------------------------------------------------------
if iplot: fig=plt.figure(figsize=((nr+1)*ux,nc*uy))

mns=[];mxs=[]
for istp in xrange(nstp):
    Z, = dat_mask(dat_raw,istp,key)
    mn, mx = find_mn(Z),find_mx(Z)
    mns.append(mn); mxs.append(mx)
    uet(time.time()-t0,head='Elapsed time for finding max and min:')
mn,mx = find_mn(mns), find_mx(mxs)
print
print 'minimum and maximum',mn, mx

if iplot:
    norm = mpl.colors.Normalize(vmin=mn,vmax=mx)
    cmap, m = mpl_lib.norm_cmap(mn=mn,mx=mx)


k = 0; axes = []
t0=time.time()
for i in xrange(nc):
    for j in xrange(nr):
        if iplot:
            ax=fig.add_subplot(g[i*10:(i+1)*10,j*10:(j+1)*10])
            ax.set_aspect('equal')
            ax.minorticks_on()
            ax.tick_params(axis='both', which='major', labelsize=15)
            ax.tick_params(axis='both', which='minor', labelsize=8)

        x,y,z=dat_mask(dat_raw,k,'X','Y',key)
        if iplot:
            cs=m.to_rgba(z)
            ax.scatter(x,y,marker='.',color=cs,s=0.02)
            ax.set_xlim(-35,35);ax.set_ylim(-35,35)
            ax.locator_params(nbins=4)
            ax.text(x=0.8,y=0.9,s='# %i'%k,verticalalignment='center',
                    horizontalalignment='center',
                    fontsize=12,transform=ax.transAxes)
        k=k+1
        if i==nc-1 and j==0:
            if iplot:
                ax.set_xlabel('X [mm]',dict(fontsize=15))
                ax.set_ylabel('Y [mm]',dict(fontsize=15))
        else: 
            if iplot:
                axes.append(ax)
        if iplot: uet(time.time()-t0,head='Elapsed time for plotting:')
        else: uet(time.time()-t0,head='Elapsed time for data masking')
        if k>=nstp: break
    if k>=nstp: break

if iplot:
    txl(fig.axes)        
    ral(axes)

    axcb=fig.add_subplot(g[(nc-1)*10:(nc)*10,(nr)*10+1:(nr)*10+2])
    mpl_lib.add_cb(ax=axcb,cmap=cmap, filled=True,
                   format='%5.3f',norm=norm,
                   ylab=r'%s '%key)

uet(time.time()-t0,head='Elapsed time:')
# Out:
# 15 15
# Elapsed time for finding max and min::   6 [sec]
# minimum and maximum 1.35823e-18 0.440768
# Elapsed time:: 323 [ ms]

# %% [markdown]
# ## -- As a first approximation, get an average with an small area

# %% [markdown]
# - Reduce data set by area

# %%
def r_area(x,y,rad,x0,y0,*args):
    """
    Reduce the data by its radius
    """
    x,y = x-x0,y-y0
    r = np.sqrt(x**2+y**2)
    zs=[]
    for arg in args:
        zs.append(arg[r<rad])
    return zs

def rr(x,y,rad,x0,y0,p,*args):
    #print len(x) ,' ->',
    zs=r_area(x,y,rad,x0,y0,*args)
    #print len(zs[0]), '->',
    
    if p<0: return zs
    elif p>0 and p<1: 
        #print len(zs[0])
        n = int(len(zs[0])*p)
        #print n
    elif p==1:
        return zs

    slc = random.choice(len(zs[0]),n)
    Z=[]
    for i in range(len(zs)):
        Z.append(zs[i][slc])
    return Z

def stat(dat):
    return np.average(dat), np.std(dat)

## application
key = 'e_vonmises'
x_,y_,z_=dat_mask(dat_raw,0,'X','Y',key)

## masking by 'area' and extract from only a portion of total data
fig=plt.figure(figsize=(7,9))
ax1=fig.add_subplot(323)
ax2=fig.add_subplot(324)
ax3=fig.add_subplot(325)
ax4=fig.add_subplot(326)

## for BB
x0=-6.0; y0=0.2;
rad_washer=16.
rad=8.

x,y,z = rr(x_,y_,30,x0,y0,1,x_,y_,z_)
ax1.scatter(x,y,marker='.',c='red')
x,y,z = rr(x_,y_,30,x0,y0,0.01,x_,y_,z_)
ax2.scatter(x,y,marker='x',c='blue')
x,y,z = rr(x_,y_,30,x0,y0,0.05,x_,y_,z_)
ax3.scatter(x,y,marker='+',c='yellow')
x,y,z = rr(x_,y_,40,x0,y0,0.05,x_,y_,z_)
ax4.scatter(x,y,marker='o',c='magenta',s=0.04)

## Trace of window of the washer
thw=np.linspace(-pi,pi)
xw=np.cos(thw)*rad_washer+x0
yw=np.sin(thw)*rad_washer+y0
xa=np.cos(thw)*rad+x0
ya=np.sin(thw)*rad+y0

ax1.plot(x0,y0,'ro')
ax1.plot(xw,yw,'w--')
ax1.plot(xa,ya,'w-')

for ax in fig.axes[1:]:
    ax.plot(x0,y0,'ko')
    ax.plot(xw,yw,'k--')
    ax.plot(xa,ya,'k-')
for ax in fig.axes:
    ax.set_aspect('equal')
plt.tight_layout()

# %%
path=os.path.split(fn_start)[0]
fn=os.path.join(path,'DIC_results.txt')
print fn
f=open(fn,'w')

keys=['e1','e2','exx','eyy','exy','sigma']
evm = []
for istp in xrange(nstp):
    if istp==0: 
        f.write('%4s '%'DIC')
        for key in keys:
            f.write('%10s_A %10s_E '%(key,key))
        f.write('\n')
    f.write('%4.4i '%dic_ind[istp])
    for key in keys:
        x, y, z= dat_mask(dat_raw,istp,'X','Y',key)
        zr = rr(x,y,rad,x0,y0,-1,z)
        avg,std= stat(zr)
        f.write(('%+11.5e '*2)%(avg, std))
    f.write('\n')
f.close()
st=os.popen('head -n 3 %s'%fn).read()
print st
# Out:
# /Users/yj/Documents/ExpDat/IFSteel/Marciniak-X-ray-IF/BB/20141029/DIC/DIC_results.txt
#  DIC         e1_A         e1_E         e2_A         e2_E        exx_A        exx_E        eyy_A        eyy_E        exy_A        exy_E      sigma_A      sigma_E
# 0000 +5.30911e-04 +4.99548e-04 -6.17400e-04 +5.36748e-04 -4.57351e-05 +7.03952e-04 -4.07542e-05 +3.76205e-04 +1.36783e-04 +5.11099e-04 +9.58568e-03 +1.11057e-03
# 0001 +5.62959e-04 +5.73333e-04 -6.62540e-04 +5.92206e-04 -5.31009e-05 +8.36920e-04 -4.64807e-05 +4.08977e-04 +5.84595e-05 +5.27157e-04 +9.54986e-03 +1.11280e-03
