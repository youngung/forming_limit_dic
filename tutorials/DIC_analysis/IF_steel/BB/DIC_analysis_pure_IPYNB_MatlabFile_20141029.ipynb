# %% [markdown]
# # Dependencies

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy.io import loadmat
from MP import progress_bar
from glob import glob
import pandas as pd
import time,os
from matplotlib import gridspec
gs=gridspec.GridSpec
uet=progress_bar.update_elapsed_time

from MP.lib import mpl_lib
from MP.lib.mpl_lib import rm_all_lab as ral
from MP.lib.mpl_lib import tune_xy_lim as txl
from matplotlib.colors import LogNorm

from MP.mat import mech

# %% [markdown]
# - Current work direction

# %%
pwd
# Out:
# u'/Users/yj/repo/FLD_DIC_XRAY/tutorials/DIC_analysis/IF_steel'

# %% [markdown]
# - Available files

# %%
ls -l /Users/yj/Documents/ExpDat/IFSteel/Marciniak-X-ray-IF/BB/20141029/DIC
# Out:
# total 2039856
# -rw-r--r--  1 yj  admin    22950 Sep  9 09:40 DIC_results.txt
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0000_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0001_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0002_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0003_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0004_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0005_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0006_0.mat*
# -rwxr-xr-x  1 yj  admin  3425917 Mar 30 14:55 IFsteel_BB-0007_0.mat*
# -rwxr-xr-x  1 yj  admin  3425917 Mar 30 14:55 IFsteel_BB-0008_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0009_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0010_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0011_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0012_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0013_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0014_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0015_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0016_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0017_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0018_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0019_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0020_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0021_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0022_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0023_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0024_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0025_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0026_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0027_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0028_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0029_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0030_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0031_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0032_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0033_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0034_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0035_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0036_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0037_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0038_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0039_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0040_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0041_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0042_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0043_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0044_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0045_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0046_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0047_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0048_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0049_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0050_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0051_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0052_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0053_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0054_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0055_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0056_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0057_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0058_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0059_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0060_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0061_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0062_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0063_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0064_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0065_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0066_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0067_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0068_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0069_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0070_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0071_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0072_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0073_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0074_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0075_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0076_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0077_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0078_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0079_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0080_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0081_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0082_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0083_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0084_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0085_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0086_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0087_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0088_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0089_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0090_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0091_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0092_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0093_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0094_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0095_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0096_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0097_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0098_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0099_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0100_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0101_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0102_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0103_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0104_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0105_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0106_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0107_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0108_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0109_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0110_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0111_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0112_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0113_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0114_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0115_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0116_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0117_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0118_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0119_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0120_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0121_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0122_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0123_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0124_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0125_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0126_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0127_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0128_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0129_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0130_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0131_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0132_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0133_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0134_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0135_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0136_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0137_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0138_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0139_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0140_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0141_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0142_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0143_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0144_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0145_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0146_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0147_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0148_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0149_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0150_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0151_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0152_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0153_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0154_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0155_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0156_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0157_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0158_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0159_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0160_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0161_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0162_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0163_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0164_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0165_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0166_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0167_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0168_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0169_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0170_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0171_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0172_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0173_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0174_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0175_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0176_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0177_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0178_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0179_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0180_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0181_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0182_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0183_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0184_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0185_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0186_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0187_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0188_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0189_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0190_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0191_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0192_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0193_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0194_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0195_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0196_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0197_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0198_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0199_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0200_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0201_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0202_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0203_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0204_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0205_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0206_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0207_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0208_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0209_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0210_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0211_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0212_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0213_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0214_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0215_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0216_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0217_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0218_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0219_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0220_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0221_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0222_0.mat*
# -rwxr-xr-x  1 yj  admin  4671729 Mar 30 14:55 IFsteel_BB-0223_0.mat*

# %% [markdown]
# - Pick a file name ( each file corresponds to single snapshot)

# %%
fn_start='/Users/yj/Documents/ExpDat/IFSteel/Marciniak-X-ray-IF/BB/20141029/DIC/IFsteel_BB-0???_0.mat'
fns=glob(fn_start)
for fn in fns:
    # print fn
    if not(os.path.isfile(fn)):
        raise IOError, '%s is not loadable'%fn

# %% [markdown]
# - Load the file and measure the file loading time

# %%
t0=time.time()
dat_raw=[]
dic_ind=[]
for i in xrange(len(fns)):
    fn =fns[i]
    dum=os.path.split(fn)[-1].split('.mat')[0][::-1]
    dum = dum[:6][::-1]
    ind=int(dum[:4:])
    # print fn,ind
    dic_ind.append(ind)
    dat_dict=loadmat(fn)
    dat_raw.append(dat_dict)
    if mod(i,10)==0: uet(time.time()-t0,head='loading time:')
# Out:
# loading time::   6 [sec]

# %% [markdown]
# - Variables available in each file

# %%
# print dat_raw[0].keys()

# %%
nstp = len(dat_raw)
nx,ny = dat_raw[-1]['sigma'].shape
print 'Total number of steps (# of DIC snapshots):', nstp
print '2D resolution (nx,ny):', nx,ny,'nx*ny:',nx*ny
# Out:
# Total number of steps (# of DIC snapshots): 224
# 2D resolution (nx,ny): 173 225 nx*ny: 38925

# %% [markdown]
# # Comparison between unfiltered raw data and data filtered by $\sigma$

# %%
fig=plt.figure(121,figsize=(8,4))
ax1=fig.add_subplot(121)
ax2=fig.add_subplot(122)
ax1.scatter(dat_raw[-1]['X'],dat_raw[-1]['Y'],marker='.',s=0.05)
ax1.set_xlim(-25,25);ax1.set_ylim(-25,25)
ax1.set_aspect('equal');ax1.set_title('Unfiltered')

ax2.scatter(dat_raw[-1]['X'][dat_raw[-1]['sigma']>0],dat_raw[-1]['Y'][dat_raw[-1]['sigma']>0],marker='.',s=0.05)
ax2.set_xlim(-25,25);ax2.set_ylim(-25,25)
ax2.set_aspect('equal');ax2.set_title(r'Filtered by $\sigma>0$')

# %% [markdown]
# # Define necessary functions

# %%
"""
Find minimum or maximum discarding +- inp and nan
"""
def find_mx(a):
    mx=None
    for i in xrange(len(a)):
        if ((a[i]>mx and a[i]!=np.inf) or mx==None) and not(np.isnan(a[i])): mx=a[i]
    return mx

def find_mn(a):
    mn=None
    for i in xrange(len(a)):
        if ((a[i]<mn and a[i]!=-np.inf) or mn==None) and not(np.isnan(a[i])): mn=a[i]
    return mn

def find_mxmn(*args):
    """
    Return max and min
    """
    maxs, mns=[], []
    for a in args:
        mns.append(find_mn(a))
        mxs.append(find_mx(a))
    return mxs, mns

## Contruct a normalized spectrum of color
def make_cb(dat,mn=None,mx=None,log=False):
    """
    Arguments
    =========
    dat
    mn  = None
    mx  = None
    log = False (If True, use LogNorm)
    """
    array = dat.flatten()
    if mn==None: mn = find_mn(array) 
    if mx==None: mx = find_mx(array)
    if log: norm=LogNorm(vmin=mn,vmax=mx)
    else:   norm=mpl.colors.Normalize(vmin=mn,vmax=mx)
    cmap,m = mpl_lib.norm_cmap(mn=mn,mx=mx,cm_name='jet')
    return cmap, norm, m

# %% [markdown]
# - Data masking bases on $\sigma$ values - those elements with $\sigma>0.$

# %%
#np.maskdat_raw[0]['q_ref']
t0=time.time()
iplot=False

for istp in xrange(nstp):
    dum=dat_raw[istp]['sigma'][dat_raw[istp]['sigma']>0]
    if iplot: plot(dum.flatten(),'x')
    if iplot: uet(time.time()-t0,head='plotting time:')
uet(time.time()-t0,head='Total time elapsed')
# Out:
# Total time elapsed:  71 [ ms]

# %% [markdown]
# - Test dat_mask can easily mask unwanted data based on its 'key' from the dictionary raw data "dat_raw" array.

# %%
def dat_mask(dat_raw,istp,*keys):
    """
    From dat_raw, mask the data
    that have its corresponding 'sigma' value 
    lower than zero.
    
    Also, return masked data for the given step.
    """
    d=[]
    k=0
    for key in keys:
        # if k==0:print np.array(dat_raw[istp][key]).shape
        array = dat_raw[istp][key]
        sigma = dat_raw[istp]['sigma']
        array = array[sigma>0]
        d.append(array)        
        k=k+1
    return d


## --
key='exx'
#key='dExx_dt'
#key='e3'
print 'key:"%s"'%key,'\n-----------'
for istp in xrange(nstp):
    x, y, z = dat_mask(dat_raw,istp,'X','Y',key)
    mx, mn  = find_mx(z), find_mn(z)
    #if istp==0: print '%5s %5s'%('min','max')
    #print '%5.3f %5.3f'%(mn, mx)

cmap, norm, m = make_cb(z,mn=mn,mx=mx)
C=m.to_rgba(z)
scatter(x,y,color=C,marker='.',s=0.3)
plt.gca().set_aspect('equal')
# Out:
# key:"exx"
# -----------

# %% [markdown]
# # PLOT XY(Z)

# %%
istp=-1
keys = 'e_vonmises'
X,Y,Z = dat_mask(dat_raw, istp, 'X','Y',key)  ## premasked array by 'sigma'
mn,mx=find_mn(Z),find_mx(Z)
cmap,norm,m = make_cb(dat=Z,mn=mn,mx=mx)

nx,= X.shape
print 'nx',nx
cs=[];X_=[];Y_=[];

c = m.to_rgba(Z)
plt.scatter(X,Y,marker='.',color=c,s=0.5)#,s=0.05)
plt.gca().set_xlim(-35,35); plt.gca().set_ylim(-35,35)
plt.gca().set_aspect('equal')
# Out:
# nx 24644

# %%
"""
Keys in the dictionary file:
----------------------------
'q_ref', 'dV_dt', 'X', 'dExx_dt', 'dEyy_dt', 'eyy', 'r_ref', 'e_vonmises', 'e3_dot', 'U', 'W', 'V', 'Y', 'dU_dt',
'Z', 'e1', 'e3', 'e2', 'dExy_dt', 'q', 'r', 'u', 'exx', 'v', 'y', 'x', 'dW_dt', 'sigma', 'gamma', 'exy'
"""
t0=time.time()
key = 'e_vonmises'

nc=int(sqrt(nstp))+1
nr=nstp/nc; nr = nr + 1
print nc,nr

if nc*nr<nstp: raise IOError, 'Insufficient cells'
g=gs(nc*10,(nr+1)*10,hspace=0,wspace=0)

ux=2;uy=2

## Switch for plotting
### ---------------------------------------------------------------
iplot=False
### ---------------------------------------------------------------
if iplot: fig=plt.figure(figsize=((nr+1)*ux,nc*uy))

mns=[];mxs=[]
for istp in xrange(nstp):
    Z, = dat_mask(dat_raw,istp,key)
    mn, mx = find_mn(Z),find_mx(Z)
    mns.append(mn); mxs.append(mx)
    uet(time.time()-t0,head='Elapsed time for finding max and min:')
mn,mx = find_mn(mns), find_mx(mxs)
print
print 'minimum and maximum',mn, mx

if iplot:
    norm = mpl.colors.Normalize(vmin=mn,vmax=mx)
    cmap, m = mpl_lib.norm_cmap(mn=mn,mx=mx)


k = 0; axes = []
t0=time.time()
for i in xrange(nc):
    for j in xrange(nr):
        if iplot:
            ax=fig.add_subplot(g[i*10:(i+1)*10,j*10:(j+1)*10])
            ax.set_aspect('equal')
            ax.minorticks_on()
            ax.tick_params(axis='both', which='major', labelsize=15)
            ax.tick_params(axis='both', which='minor', labelsize=8)

        x,y,z=dat_mask(dat_raw,k,'X','Y',key)
        if iplot:
            cs=m.to_rgba(z)
            ax.scatter(x,y,marker='.',color=cs,s=0.02)
            ax.set_xlim(-35,35);ax.set_ylim(-35,35)
            ax.locator_params(nbins=4)
            ax.text(x=0.8,y=0.9,s='# %i'%k,verticalalignment='center',
                    horizontalalignment='center',
                    fontsize=12,transform=ax.transAxes)
        k=k+1
        if i==nc-1 and j==0:
            if iplot:
                ax.set_xlabel('X [mm]',dict(fontsize=15))
                ax.set_ylabel('Y [mm]',dict(fontsize=15))
        else: 
            if iplot:
                axes.append(ax)
        if iplot: uet(time.time()-t0,head='Elapsed time for plotting:')
        else: uet(time.time()-t0,head='Elapsed time for data masking')
        if k>=nstp: break
    if k>=nstp: break

if iplot:
    txl(fig.axes)        
    ral(axes)

    axcb=fig.add_subplot(g[(nc-1)*10:(nc)*10,(nr)*10+1:(nr)*10+2])
    mpl_lib.add_cb(ax=axcb,cmap=cmap, filled=True,
                   format='%5.3f',norm=norm,
                   ylab=r'%s '%key)

uet(time.time()-t0,head='Elapsed time:')
# Out:
# 15 15
# Elapsed time for finding max and min::   6 [sec]
# minimum and maximum 1.35823e-18 0.440768
# Elapsed time:: 326 [ ms]

# %% [markdown]
# ## -- As a first approximation, get an average with an small area

# %% [markdown]
# - Reduce data set by area

# %%
def r_area(x,y,rad,x0,y0,*args):
    """
    Reduce the data by its radius
    """
    x,y = x-x0,y-y0
    r = np.sqrt(x**2+y**2)
    zs=[]
    for arg in args:
        zs.append(arg[r<rad])
    return zs

def rr(x,y,rad,x0,y0,p,*args):
    #print len(x) ,' ->',
    zs=r_area(x,y,rad,x0,y0,*args)
    #print len(zs[0]), '->',
    
    if p<0: return zs
    elif p>0 and p<1: 
        #print len(zs[0])
        n = int(len(zs[0])*p)
        #print n
    elif p==1:
        return zs

    slc = random.choice(len(zs[0]),n)
    Z=[]
    for i in range(len(zs)):
        Z.append(zs[i][slc])
    return Z

def stat(dat):
    return np.average(dat), np.std(dat)
    


## application
key = 'e_vonmises'
x_,y_,z_=dat_mask(dat_raw,0,'X','Y',key)

## masking by 'area' and extract from only a portion of total data
fig=plt.figure()
ax1=fig.add_subplot(221)
ax2=fig.add_subplot(222)
ax3=fig.add_subplot(223)
ax4=fig.add_subplot(224)
x,y,z = rr(x_,y_,30,-5,0,1,x_,y_,z_)
ax1.scatter(x,y,marker='.',c='red')
x,y,z = rr(x_,y_,30,-5,0,0.01,x_,y_,z_)
ax2.scatter(x,y,marker='x',c='blue')
x,y,z = rr(x_,y_,30,-5,0,0.05,x_,y_,z_)
ax3.scatter(x,y,marker='+',c='yellow')
x,y,z = rr(x_,y_,40,-5,0,0.05,x_,y_,z_)
ax4.scatter(x,y,marker='o',c='magenta')

# %%
path=os.path.split(fn_start)[0]
fn=os.path.join(path,'DIC_results.txt')
print fn
f=open(fn,'w')

keys=['e1','e2','exx','eyy','exy','sigma']
evm = []
for istp in xrange(nstp):
    if istp==0: 
        f.write('%4s '%'DIC')
        for key in keys:
            f.write('%5s_A %5s_E '%(key,key))
        f.write('\n')
    f.write('%4.4i '%dic_ind[istp])
    for key in keys:
        x, y, z= dat_mask(dat_raw,istp,'X','Y',key)
        zr = rr(x,y,10,-5,0,-1,z)
        avg,std= stat(zr)
        f.write('%7.4f %7.4f '%(avg, std))
    f.write('\n')
f.close()
st=os.popen('cat %s'%fn).read()
print st
# Out:
# /Users/yj/Documents/ExpDat/IFSteel/Marciniak-X-ray-IF/BB/20141029/DIC/DIC_results.txt
#  DIC    e1_A    e1_E    e2_A    e2_E   exx_A   exx_E   eyy_A   eyy_E   exy_A   exy_E sigma_A sigma_E
# 0000  0.0005  0.0005 -0.0007  0.0006 -0.0001  0.0008 -0.0000  0.0004  0.0001  0.0005  0.0098  0.0013
# 0001  0.0006  0.0006 -0.0007  0.0006 -0.0001  0.0009 -0.0000  0.0004  0.0001  0.0005  0.0098  0.0013
# 0002  0.0006  0.0006 -0.0006  0.0006 -0.0000  0.0008 -0.0000  0.0004 -0.0000  0.0005  0.0098  0.0013
# 0003 -0.0000  0.0000 -0.0000  0.0000 -0.0000  0.0000 -0.0000  0.0000 -0.0000  0.0000  0.0124  0.0014
# 0004  0.0007  0.0006 -0.0007  0.0007 -0.0001  0.0009  0.0001  0.0005  0.0002  0.0006  0.0128  0.0020
# 0005  0.0009  0.0006 -0.0005  0.0007  0.0002  0.0008  0.0003  0.0005  0.0002  0.0006  0.0081  0.0010
# 0006  0.0009  0.0006 -0.0005  0.0007  0.0001  0.0008  0.0002  0.0005  0.0002  0.0006  0.0079  0.0010
# 0007  0.0008  0.0006 -0.0006  0.0007 -0.0000  0.0009  0.0002  0.0005  0.0002  0.0006  0.0079  0.0010
# 0008  0.0008  0.0006 -0.0006  0.0007 -0.0000  0.0008  0.0002  0.0005  0.0002  0.0006  0.0080  0.0010
# 0009  0.0008  0.0006 -0.0006  0.0007  0.0001  0.0009  0.0002  0.0005  0.0002  0.0006  0.0081  0.0010
# 0010  0.0008  0.0006 -0.0006  0.0007 -0.0000  0.0009  0.0002  0.0005  0.0002  0.0006  0.0081  0.0010
# 0011  0.0009  0.0006 -0.0006  0.0008  0.0000  0.0009  0.0002  0.0005  0.0002  0.0006  0.0081  0.0010
# 0012  0.0008  0.0006 -0.0006  0.0008  0.0000  0.0009  0.0002  0.0005  0.0002  0.0006  0.0079  0.0010
# 0013  0.0009  0.0007 -0.0007  0.0008  0.0000  0.0010  0.0002  0.0006  0.0002  0.0007  0.0079  0.0010
# 0014  0.0010  0.0007 -0.0006  0.0008  0.0002  0.0010  0.0003  0.0005  0.0003  0.0007  0.0079  0.0010
# 0015  0.0010  0.0007 -0.0006  0.0008  0.0001  0.0010  0.0003  0.0006  0.0002  0.0007  0.0080  0.0010
# 0016  0.0011  0.0007 -0.0005  0.0008  0.0002  0.0010  0.0004  0.0006  0.0002  0.0007  0.0080  0.0010
# 0017  0.0011  0.0007 -0.0005  0.0008  0.0002  0.0010  0.0004  0.0006  0.0002  0.0007  0.0080  0.0010
# 0018  0.0012  0.0007 -0.0004  0.0008  0.0003  0.0010  0.0005  0.0006  0.0002  0.0007  0.0080  0.0010
# 0019  0.0012  0.0007 -0.0004  0.0008  0.0003  0.0009  0.0005  0.0006  0.0002  0.0007  0.0080  0.0010
# 0020  0.0012  0.0007 -0.0004  0.0008  0.0003  0.0010  0.0006  0.0006  0.0002  0.0007  0.0079  0.0010
# 0021  0.0013  0.0007 -0.0003  0.0008  0.0004  0.0010  0.0006  0.0006  0.0002  0.0007  0.0079  0.0010
# 0022  0.0013  0.0007 -0.0003  0.0009  0.0004  0.0010  0.0006  0.0006  0.0002  0.0007  0.0079  0.0010
# 0023  0.0014  0.0008 -0.0003  0.0009  0.0004  0.0010  0.0007  0.0007  0.0002  0.0008  0.0078  0.0010
# 0024  0.0014  0.0007 -0.0002  0.0009  0.0005  0.0011  0.0007  0.0006  0.0002  0.0007  0.0078  0.0010
# 0025  0.0016  0.0008 -0.0001  0.0009  0.0007  0.0011  0.0008  0.0007  0.0003  0.0008  0.0078  0.0009
# 0026  0.0015  0.0007 -0.0002  0.0009  0.0005  0.0010  0.0007  0.0007  0.0002  0.0007  0.0077  0.0009
# 0027  0.0015  0.0008 -0.0002  0.0009  0.0005  0.0011  0.0007  0.0007  0.0002  0.0007  0.0078  0.0010
# 0028  0.0015  0.0008 -0.0002  0.0009  0.0005  0.0011  0.0007  0.0007  0.0002  0.0008  0.0078  0.0010
# 0029  0.0015  0.0008 -0.0002  0.0009  0.0006  0.0010  0.0007  0.0007  0.0002  0.0008  0.0078  0.0010
# 0030  0.0015  0.0008 -0.0003  0.0009  0.0005  0.0011  0.0007  0.0007  0.0002  0.0008  0.0078  0.0010
# 0031  0.0016  0.0008 -0.0002  0.0009  0.0006  0.0011  0.0008  0.0007  0.0002  0.0008  0.0078  0.0010
# 0032  0.0015  0.0008 -0.0002  0.0009  0.0005  0.0011  0.0007  0.0007  0.0002  0.0008  0.0078  0.0010
# 0033  0.0016  0.0008 -0.0002  0.0009  0.0006  0.0011  0.0008  0.0007  0.0002  0.0008  0.0078  0.0010
# 0034  0.0016  0.0008 -0.0002  0.0009  0.0006  0.0011  0.0008  0.0008  0.0002  0.0008  0.0078  0.0009
# 0035  0.0016  0.0008 -0.0002  0.0010  0.0006  0.0011  0.0008  0.0007  0.0002  0.0008  0.0078  0.0010
# 0036  0.0015  0.0009 -0.0003  0.0009  0.0005  0.0011  0.0007  0.0008  0.0001  0.0008  0.0079  0.0010
# 0037  0.0016  0.0009 -0.0002  0.0010  0.0007  0.0012  0.0008  0.0008  0.0002  0.0008  0.0078  0.0009
# 0038  0.0018  0.0009 -0.0001  0.0010  0.0008  0.0012  0.0009  0.0008  0.0002  0.0008  0.0078  0.0010
# 0039  0.0018  0.0008 -0.0001  0.0010  0.0008  0.0012  0.0010  0.0008  0.0003  0.0008  0.0078  0.0010
# 0040  0.0018  0.0009 -0.0000  0.0010  0.0008  0.0012  0.0009  0.0008  0.0002  0.0008  0.0079  0.0009
# 0041  0.0019  0.0009  0.0001  0.0010  0.0009  0.0012  0.0010  0.0008  0.0000  0.0008  0.0078  0.0010
# 0042  0.0020  0.0009  0.0001  0.0010  0.0009  0.0012  0.0011  0.0008  0.0002  0.0008  0.0078  0.0010
# 0043  0.0020  0.0009  0.0001  0.0010  0.0010  0.0012  0.0012  0.0008  0.0002  0.0008  0.0078  0.0010
# 0044  0.0022  0.0009  0.0003  0.0010  0.0012  0.0012  0.0012  0.0008  0.0002  0.0008  0.0078  0.0010
# 0045  0.0023  0.0009  0.0004  0.0010  0.0013  0.0012  0.0014  0.0009  0.0002  0.0008  0.0078  0.0009
# 0046  0.0024  0.0009  0.0004  0.0010  0.0014  0.0012  0.0014  0.0009  0.0002  0.0008  0.0078  0.0010
# 0047  0.0026  0.0009  0.0006  0.0010  0.0015  0.0012  0.0016  0.0008  0.0002  0.0008  0.0078  0.0010
# 0048  0.0027  0.0009  0.0007  0.0010  0.0017  0.0012  0.0018  0.0009  0.0002  0.0008  0.0078  0.0010
# 0049  0.0029  0.0009  0.0009  0.0010  0.0018  0.0012  0.0020  0.0009  0.0003  0.0008  0.0078  0.0009
# 0050  0.0030  0.0009  0.0010  0.0010  0.0019  0.0012  0.0021  0.0009  0.0002  0.0009  0.0078  0.0010
# 0051  0.0032  0.0009  0.0013  0.0010  0.0022  0.0013  0.0023  0.0009  0.0002  0.0008  0.0078  0.0009
# 0052  0.0034  0.0009  0.0014  0.0011  0.0023  0.0013  0.0024  0.0009  0.0002  0.0008  0.0078  0.0009
# 0053  0.0037  0.0009  0.0016  0.0010  0.0026  0.0013  0.0026  0.0009  0.0002  0.0009  0.0078  0.0009
# 0054  0.0038  0.0010  0.0018  0.0011  0.0028  0.0013  0.0029  0.0009  0.0002  0.0009  0.0078  0.0009
# 0055  0.0040  0.0009  0.0020  0.0011  0.0030  0.0013  0.0031  0.0009  0.0002  0.0009  0.0078  0.0009
# 0056  0.0042  0.0010  0.0022  0.0011  0.0032  0.0013  0.0032  0.0009  0.0002  0.0009  0.0078  0.0009
# 0057  0.0045  0.0009  0.0024  0.0011  0.0034  0.0013  0.0035  0.0009  0.0003  0.0009  0.0078  0.0009
# 0058  0.0047  0.0010  0.0026  0.0011  0.0036  0.0013  0.0037  0.0009  0.0002  0.0009  0.0078  0.0009
# 0059  0.0049  0.0010  0.0029  0.0011  0.0038  0.0013  0.0039  0.0009  0.0002  0.0009  0.0078  0.0009
# 0060  0.0051  0.0010  0.0030  0.0011  0.0040  0.0014  0.0042  0.0009  0.0002  0.0009  0.0078  0.0009
# 0061  0.0054  0.0010  0.0033  0.0011  0.0043  0.0014  0.0044  0.0009  0.0002  0.0009  0.0078  0.0009
# 0062  0.0056  0.0010  0.0035  0.0011  0.0045  0.0014  0.0046  0.0009  0.0002  0.0009  0.0077  0.0009
# 0063  0.0059  0.0010  0.0038  0.0011  0.0048  0.0014  0.0049  0.0009  0.0002  0.0009  0.0078  0.0009
# 0064  0.0062  0.0010  0.0040  0.0011  0.0051  0.0014  0.0052  0.0009  0.0002  0.0009  0.0078  0.0009
# 0065  0.0064  0.0010  0.0043  0.0011  0.0054  0.0014  0.0054  0.0009  0.0002  0.0009  0.0078  0.0010
# 0066  0.0067  0.0010  0.0046  0.0011  0.0056  0.0013  0.0057  0.0009  0.0002  0.0009  0.0077  0.0009
# 0067  0.0070  0.0010  0.0049  0.0012  0.0060  0.0014  0.0060  0.0009  0.0002  0.0009  0.0078  0.0010
# 0068  0.0073  0.0010  0.0051  0.0011  0.0062  0.0013  0.0062  0.0009  0.0002  0.0009  0.0078  0.0009
# 0069  0.0076  0.0010  0.0054  0.0011  0.0065  0.0014  0.0065  0.0009  0.0002  0.0009  0.0077  0.0009
# 0070  0.0078  0.0010  0.0057  0.0011  0.0067  0.0014  0.0068  0.0009  0.0002  0.0009  0.0078  0.0009
# 0071  0.0082  0.0010  0.0060  0.0011  0.0071  0.0014  0.0071  0.0009  0.0002  0.0009  0.0078  0.0009
# 0072  0.0085  0.0010  0.0063  0.0011  0.0074  0.0014  0.0074  0.0010  0.0002  0.0009  0.0077  0.0010
# 0073  0.0088  0.0010  0.0066  0.0012  0.0076  0.0014  0.0077  0.0010  0.0002  0.0009  0.0078  0.0010
# 0074  0.0091  0.0010  0.0069  0.0012  0.0080  0.0014  0.0080  0.0010  0.0003  0.0010  0.0078  0.0009
# 0075  0.0095  0.0010  0.0073  0.0012  0.0084  0.0014  0.0084  0.0010  0.0003  0.0009  0.0078  0.0010
# 0076  0.0097  0.0010  0.0076  0.0011  0.0086  0.0013  0.0087  0.0010  0.0002  0.0009  0.0078  0.0009
# 0077  0.0100  0.0010  0.0079  0.0011  0.0090  0.0014  0.0089  0.0010  0.0002  0.0009  0.0078  0.0009
# 0078  0.0104  0.0010  0.0082  0.0011  0.0093  0.0014  0.0093  0.0010  0.0003  0.0010  0.0078  0.0009
# 0079  0.0108  0.0010  0.0086  0.0012  0.0096  0.0014  0.0097  0.0010  0.0003  0.0009  0.0078  0.0009
# 0080  0.0111  0.0010  0.0088  0.0012  0.0099  0.0014  0.0100  0.0010  0.0003  0.0010  0.0078  0.0009
# 0081  0.0115  0.0010  0.0092  0.0012  0.0103  0.0014  0.0104  0.0010  0.0003  0.0009  0.0078  0.0009
# 0082  0.0118  0.0010  0.0096  0.0012  0.0107  0.0014  0.0107  0.0010  0.0002  0.0009  0.0078  0.0009
# 0083  0.0122  0.0010  0.0099  0.0012  0.0110  0.0014  0.0111  0.0010  0.0002  0.0010  0.0078  0.0009
# 0084  0.0125  0.0010  0.0102  0.0012  0.0113  0.0014  0.0114  0.0010  0.0002  0.0010  0.0078  0.0009
# 0085  0.0129  0.0010  0.0106  0.0012  0.0117  0.0014  0.0118  0.0010  0.0002  0.0010  0.0078  0.0009
# 0086  0.0133  0.0010  0.0110  0.0012  0.0121  0.0014  0.0122  0.0010  0.0002  0.0010  0.0078  0.0009
# 0087  0.0137  0.0010  0.0114  0.0012  0.0125  0.0014  0.0125  0.0010  0.0003  0.0009  0.0078  0.0009
# 0088  0.0140  0.0010  0.0118  0.0012  0.0129  0.0015  0.0129  0.0010  0.0002  0.0010  0.0078  0.0009
# 0089  0.0145  0.0011  0.0122  0.0012  0.0134  0.0015  0.0133  0.0010  0.0002  0.0010  0.0078  0.0009
# 0090  0.0148  0.0011  0.0125  0.0012  0.0137  0.0015  0.0137  0.0010  0.0002  0.0010  0.0078  0.0009
# 0091  0.0152  0.0011  0.0129  0.0012  0.0141  0.0015  0.0141  0.0010  0.0003  0.0010  0.0078  0.0009
# 0092  0.0156  0.0011  0.0133  0.0012  0.0145  0.0015  0.0145  0.0010  0.0002  0.0010  0.0078  0.0009
# 0093  0.0160  0.0011  0.0137  0.0012  0.0149  0.0015  0.0148  0.0010  0.0003  0.0010  0.0078  0.0009
# 0094  0.0164  0.0011  0.0141  0.0013  0.0153  0.0015  0.0153  0.0010  0.0003  0.0010  0.0078  0.0009
# 0095  0.0168  0.0011  0.0145  0.0012  0.0157  0.0015  0.0157  0.0010  0.0002  0.0010  0.0078  0.0009
# 0096  0.0174  0.0011  0.0150  0.0012  0.0162  0.0015  0.0162  0.0010  0.0003  0.0010  0.0078  0.0009
# 0097  0.0177  0.0011  0.0154  0.0012  0.0166  0.0015  0.0165  0.0010  0.0002  0.0010  0.0078  0.0009
# 0098  0.0181  0.0011  0.0158  0.0012  0.0170  0.0015  0.0169  0.0010  0.0003  0.0010  0.0078  0.0009
# 0099  0.0186  0.0011  0.0162  0.0012  0.0175  0.0015  0.0173  0.0010  0.0002  0.0010  0.0078  0.0009
# 0100  0.0190  0.0011  0.0166  0.0012  0.0178  0.0015  0.0178  0.0010  0.0003  0.0010  0.0078  0.0009
# 0101  0.0195  0.0011  0.0171  0.0013  0.0183  0.0015  0.0182  0.0010  0.0002  0.0010  0.0078  0.0009
# 0102  0.0199  0.0011  0.0175  0.0012  0.0187  0.0015  0.0187  0.0010  0.0003  0.0010  0.0078  0.0009
# 0103  0.0204  0.0011  0.0180  0.0013  0.0193  0.0015  0.0192  0.0010  0.0003  0.0010  0.0078  0.0010
# 0104  0.0208  0.0011  0.0185  0.0013  0.0197  0.0015  0.0196  0.0010  0.0003  0.0010  0.0079  0.0010
# 0105  0.0214  0.0011  0.0189  0.0013  0.0202  0.0016  0.0201  0.0011  0.0003  0.0010  0.0078  0.0010
# 0106  0.0218  0.0011  0.0194  0.0013  0.0207  0.0016  0.0205  0.0010  0.0003  0.0010  0.0078  0.0010
# 0107  0.0223  0.0011  0.0198  0.0013  0.0211  0.0016  0.0210  0.0011  0.0003  0.0010  0.0078  0.0010
# 0108  0.0228  0.0011  0.0203  0.0013  0.0216  0.0016  0.0214  0.0011  0.0002  0.0010  0.0078  0.0009
# 0109  0.0233  0.0012  0.0208  0.0013  0.0222  0.0016  0.0219  0.0011  0.0003  0.0010  0.0078  0.0009
# 0110  0.0238  0.0011  0.0213  0.0013  0.0226  0.0016  0.0225  0.0011  0.0003  0.0010  0.0079  0.0010
# 0111  0.0243  0.0011  0.0218  0.0013  0.0231  0.0016  0.0230  0.0011  0.0003  0.0010  0.0079  0.0010
# 0112  0.0248  0.0011  0.0223  0.0013  0.0236  0.0016  0.0235  0.0011  0.0003  0.0010  0.0078  0.0010
# 0113  0.0253  0.0012  0.0228  0.0013  0.0241  0.0016  0.0240  0.0011  0.0003  0.0011  0.0078  0.0010
# 0114  0.0258  0.0011  0.0234  0.0013  0.0247  0.0016  0.0245  0.0011  0.0003  0.0011  0.0079  0.0010
# 0115  0.0264  0.0012  0.0239  0.0014  0.0252  0.0016  0.0250  0.0011  0.0003  0.0011  0.0078  0.0010
# 0116  0.0270  0.0012  0.0244  0.0014  0.0257  0.0017  0.0256  0.0011  0.0003  0.0011  0.0079  0.0010
# 0117  0.0275  0.0012  0.0249  0.0013  0.0263  0.0017  0.0260  0.0011  0.0003  0.0011  0.0079  0.0010
# 0118  0.0280  0.0012  0.0254  0.0014  0.0268  0.0017  0.0266  0.0011  0.0003  0.0011  0.0079  0.0010
# 0119  0.0286  0.0012  0.0259  0.0014  0.0273  0.0017  0.0272  0.0011  0.0003  0.0011  0.0079  0.0010
# 0120  0.0292  0.0012  0.0265  0.0014  0.0280  0.0017  0.0277  0.0011  0.0003  0.0011  0.0079  0.0010
# 0121  0.0297  0.0012  0.0271  0.0013  0.0285  0.0017  0.0283  0.0011  0.0003  0.0011  0.0079  0.0010
# 0122  0.0303  0.0012  0.0277  0.0014  0.0291  0.0017  0.0289  0.0011  0.0003  0.0011  0.0079  0.0010
# 0123  0.0308  0.0012  0.0282  0.0014  0.0296  0.0018  0.0294  0.0011  0.0003  0.0011  0.0079  0.0010
# 0124  0.0314  0.0012  0.0288  0.0014  0.0302  0.0017  0.0300  0.0011  0.0003  0.0011  0.0079  0.0010
# 0125  0.0321  0.0012  0.0294  0.0014  0.0308  0.0017  0.0306  0.0011  0.0003  0.0011  0.0079  0.0010
# 0126  0.0327  0.0012  0.0300  0.0014  0.0315  0.0018  0.0312  0.0011  0.0003  0.0011  0.0079  0.0010
# 0127  0.0333  0.0013  0.0306  0.0014  0.0321  0.0018  0.0317  0.0012  0.0003  0.0011  0.0079  0.0010
# 0128  0.0339  0.0013  0.0312  0.0014  0.0327  0.0018  0.0324  0.0011  0.0003  0.0011  0.0079  0.0009
# 0129  0.0345  0.0013  0.0318  0.0014  0.0333  0.0018  0.0330  0.0012  0.0003  0.0011  0.0079  0.0010
# 0130  0.0351  0.0013  0.0324  0.0014  0.0339  0.0018  0.0336  0.0012  0.0003  0.0011  0.0079  0.0010
# 0131  0.0357  0.0013  0.0330  0.0014  0.0345  0.0018  0.0342  0.0012  0.0003  0.0011  0.0080  0.0010
# 0132  0.0363  0.0013  0.0336  0.0014  0.0352  0.0019  0.0348  0.0012  0.0002  0.0011  0.0080  0.0010
# 0133  0.0370  0.0012  0.0342  0.0015  0.0358  0.0018  0.0355  0.0012  0.0004  0.0011  0.0080  0.0010
# 0134  0.0377  0.0013  0.0349  0.0014  0.0364  0.0018  0.0361  0.0012  0.0004  0.0011  0.0080  0.0010
# 0135  0.0384  0.0013  0.0356  0.0015  0.0372  0.0018  0.0369  0.0012  0.0004  0.0011  0.0080  0.0010
# 0136  0.0390  0.0013  0.0362  0.0015  0.0378  0.0019  0.0374  0.0012  0.0003  0.0011  0.0080  0.0010
# 0137  0.0397  0.0013  0.0368  0.0015  0.0385  0.0019  0.0381  0.0012  0.0003  0.0012  0.0080  0.0010
# 0138  0.0404  0.0013  0.0375  0.0015  0.0392  0.0019  0.0387  0.0012  0.0003  0.0012  0.0080  0.0010
# 0139  0.0411  0.0014  0.0382  0.0015  0.0399  0.0019  0.0394  0.0012  0.0003  0.0012  0.0080  0.0010
# 0140  0.0417  0.0013  0.0389  0.0015  0.0405  0.0019  0.0401  0.0012  0.0004  0.0012  0.0080  0.0010
# 0141  0.0424  0.0013  0.0396  0.0015  0.0413  0.0019  0.0408  0.0012  0.0003  0.0012  0.0080  0.0010
# 0142  0.0431  0.0013  0.0402  0.0015  0.0419  0.0019  0.0414  0.0013  0.0004  0.0012  0.0080  0.0010
# 0143  0.0438  0.0013  0.0409  0.0016  0.0426  0.0019  0.0421  0.0013  0.0004  0.0012  0.0080  0.0010
# 0144  0.0445  0.0014  0.0416  0.0015  0.0433  0.0019  0.0428  0.0013  0.0004  0.0012  0.0080  0.0010
# 0145  0.0453  0.0014  0.0423  0.0015  0.0441  0.0019  0.0435  0.0013  0.0004  0.0012  0.0080  0.0010
# 0146  0.0460  0.0014  0.0430  0.0016  0.0448  0.0020  0.0442  0.0013  0.0004  0.0012  0.0080  0.0010
# 0147  0.0466  0.0013  0.0437  0.0015  0.0455  0.0019  0.0449  0.0013  0.0004  0.0012  0.0081  0.0010
# 0148  0.0474  0.0014  0.0444  0.0015  0.0462  0.0019  0.0456  0.0013  0.0003  0.0012  0.0081  0.0010
# 0149  0.0481  0.0014  0.0452  0.0015  0.0469  0.0019  0.0464  0.0013  0.0004  0.0011  0.0081  0.0010
# 0150  0.0489  0.0014  0.0459  0.0015  0.0477  0.0019  0.0471  0.0013  0.0004  0.0012  0.0081  0.0010
# 0151  0.0496  0.0013  0.0467  0.0015  0.0485  0.0019  0.0478  0.0013  0.0004  0.0012  0.0081  0.0010
# 0152  0.0504  0.0014  0.0474  0.0016  0.0493  0.0019  0.0486  0.0013  0.0004  0.0012  0.0081  0.0010
# 0153  0.0512  0.0014  0.0481  0.0016  0.0500  0.0020  0.0493  0.0013  0.0004  0.0012  0.0081  0.0010
# 0154  0.0519  0.0014  0.0489  0.0015  0.0508  0.0019  0.0501  0.0013  0.0005  0.0012  0.0081  0.0010
# 0155  0.0527  0.0014  0.0497  0.0016  0.0516  0.0019  0.0508  0.0013  0.0004  0.0012  0.0081  0.0010
# 0156  0.0535  0.0014  0.0505  0.0015  0.0524  0.0019  0.0516  0.0014  0.0004  0.0012  0.0081  0.0010
# 0157  0.0543  0.0014  0.0512  0.0016  0.0531  0.0019  0.0524  0.0013  0.0005  0.0012  0.0081  0.0010
# 0158  0.0551  0.0014  0.0520  0.0015  0.0539  0.0019  0.0532  0.0014  0.0004  0.0012  0.0081  0.0010
# 0159  0.0559  0.0014  0.0528  0.0016  0.0547  0.0019  0.0539  0.0014  0.0005  0.0012  0.0081  0.0010
# 0160  0.0567  0.0014  0.0536  0.0016  0.0555  0.0020  0.0547  0.0014  0.0004  0.0012  0.0081  0.0010
# 0161  0.0575  0.0014  0.0544  0.0016  0.0563  0.0019  0.0555  0.0014  0.0005  0.0012  0.0082  0.0010
# 0162  0.0584  0.0015  0.0552  0.0016  0.0572  0.0020  0.0564  0.0014  0.0005  0.0013  0.0082  0.0010
# 0163  0.0592  0.0015  0.0560  0.0016  0.0580  0.0020  0.0572  0.0014  0.0005  0.0013  0.0082  0.0010
# 0164  0.0600  0.0015  0.0568  0.0017  0.0589  0.0020  0.0580  0.0015  0.0005  0.0013  0.0082  0.0010
# 0165  0.0609  0.0015  0.0576  0.0017  0.0597  0.0020  0.0588  0.0014  0.0005  0.0013  0.0082  0.0010
# 0166  0.0617  0.0015  0.0585  0.0016  0.0606  0.0020  0.0596  0.0014  0.0005  0.0013  0.0082  0.0010
# 0167  0.0626  0.0015  0.0593  0.0017  0.0614  0.0020  0.0605  0.0015  0.0005  0.0013  0.0082  0.0010
# 0168  0.0635  0.0015  0.0601  0.0017  0.0622  0.0020  0.0614  0.0015  0.0006  0.0013  0.0082  0.0010
# 0169  0.0644  0.0016  0.0610  0.0017  0.0632  0.0020  0.0622  0.0015  0.0005  0.0013  0.0082  0.0010
# 0170  0.0653  0.0016  0.0619  0.0017  0.0641  0.0020  0.0631  0.0015  0.0005  0.0013  0.0083  0.0010
# 0171  0.0662  0.0016  0.0628  0.0017  0.0650  0.0021  0.0639  0.0015  0.0005  0.0014  0.0083  0.0010
# 0172  0.0671  0.0016  0.0636  0.0017  0.0658  0.0021  0.0648  0.0015  0.0005  0.0013  0.0083  0.0010
# 0173  0.0679  0.0016  0.0645  0.0017  0.0667  0.0021  0.0657  0.0015  0.0005  0.0013  0.0083  0.0010
# 0174  0.0689  0.0016  0.0654  0.0017  0.0676  0.0021  0.0666  0.0016  0.0005  0.0014  0.0083  0.0010
# 0175  0.0698  0.0017  0.0662  0.0018  0.0685  0.0022  0.0675  0.0016  0.0006  0.0014  0.0083  0.0010
# 0176  0.0708  0.0017  0.0673  0.0017  0.0696  0.0021  0.0685  0.0016  0.0005  0.0014  0.0083  0.0010
# 0177  0.0717  0.0017  0.0681  0.0018  0.0705  0.0021  0.0694  0.0016  0.0006  0.0014  0.0083  0.0010
# 0178  0.0726  0.0017  0.0691  0.0017  0.0714  0.0021  0.0703  0.0016  0.0005  0.0014  0.0083  0.0010
# 0179  0.0736  0.0017  0.0701  0.0017  0.0724  0.0021  0.0713  0.0016  0.0005  0.0014  0.0084  0.0010
# 0180  0.0746  0.0017  0.0710  0.0018  0.0734  0.0021  0.0722  0.0016  0.0006  0.0014  0.0083  0.0010
# 0181  0.0756  0.0017  0.0719  0.0018  0.0744  0.0022  0.0732  0.0016  0.0005  0.0014  0.0083  0.0010
# 0182  0.0765  0.0017  0.0729  0.0018  0.0753  0.0022  0.0742  0.0017  0.0006  0.0014  0.0084  0.0011
# 0183  0.0776  0.0018  0.0739  0.0018  0.0763  0.0022  0.0751  0.0017  0.0006  0.0015  0.0084  0.0011
# 0184  0.0785  0.0017  0.0749  0.0018  0.0773  0.0022  0.0761  0.0017  0.0005  0.0014  0.0084  0.0011
# 0185  0.0796  0.0017  0.0759  0.0018  0.0784  0.0022  0.0771  0.0017  0.0006  0.0014  0.0084  0.0011
# 0186  0.0806  0.0017  0.0769  0.0018  0.0793  0.0022  0.0781  0.0017  0.0006  0.0014  0.0084  0.0011
# 0187  0.0816  0.0018  0.0778  0.0018  0.0804  0.0022  0.0791  0.0017  0.0005  0.0014  0.0084  0.0010
# 0188  0.0827  0.0018  0.0789  0.0018  0.0814  0.0022  0.0802  0.0017  0.0006  0.0014  0.0085  0.0011
# 0189  0.0837  0.0018  0.0799  0.0018  0.0825  0.0022  0.0812  0.0018  0.0006  0.0014  0.0085  0.0011
# 0190  0.0848  0.0018  0.0810  0.0018  0.0835  0.0023  0.0823  0.0017  0.0006  0.0014  0.0085  0.0011
# 0191  0.0859  0.0018  0.0821  0.0018  0.0846  0.0022  0.0833  0.0018  0.0006  0.0014  0.0084  0.0011
# 0192  0.0869  0.0018  0.0831  0.0018  0.0856  0.0022  0.0844  0.0018  0.0006  0.0014  0.0085  0.0011
# 0193  0.0880  0.0018  0.0842  0.0018  0.0868  0.0023  0.0855  0.0018  0.0006  0.0015  0.0085  0.0011
# 0194  0.0892  0.0018  0.0853  0.0019  0.0879  0.0023  0.0866  0.0018  0.0006  0.0015  0.0085  0.0010
# 0195  0.0902  0.0018  0.0863  0.0019  0.0889  0.0023  0.0876  0.0018  0.0006  0.0015  0.0085  0.0011
# 0196  0.0914  0.0019  0.0874  0.0019  0.0901  0.0024  0.0887  0.0018  0.0006  0.0015  0.0085  0.0011
# 0197  0.0925  0.0018  0.0886  0.0020  0.0912  0.0023  0.0899  0.0019  0.0007  0.0015  0.0086  0.0011
# 0198  0.0931  0.0019  0.0891  0.0020  0.0918  0.0023  0.0905  0.0019  0.0007  0.0015  0.0085  0.0011
# 0199  0.0932  0.0019  0.0891  0.0020  0.0918  0.0024  0.0905  0.0019  0.0007  0.0015  0.0087  0.0011
# 0200  0.0932  0.0019  0.0892  0.0019  0.0919  0.0024  0.0905  0.0019  0.0006  0.0015  0.0087  0.0011
# 0201  0.0932  0.0019  0.0892  0.0020  0.0919  0.0023  0.0906  0.0019  0.0007  0.0015  0.0087  0.0011
# 0202  0.0932  0.0019  0.0891  0.0020  0.0918  0.0024  0.0905  0.0019  0.0006  0.0016  0.0087  0.0011
# 0203  0.0932  0.0019  0.0892  0.0020  0.0919  0.0024  0.0905  0.0019  0.0006  0.0015  0.0087  0.0011
# 0204  0.0933  0.0019  0.0892  0.0020  0.0919  0.0024  0.0906  0.0019  0.0007  0.0015  0.0092  0.0012
# 0205  0.1874  0.0031  0.1816  0.0031  0.1847  0.0034  0.1844  0.0036  0.0005  0.0024  0.0179  0.0033
# 0206  0.1875  0.0032  0.1817  0.0031  0.1848  0.0034  0.1844  0.0036  0.0005  0.0024  0.0101  0.0014
# 0207  0.2757  0.0046  0.2675  0.0043  0.2701  0.0044  0.2731  0.0054  0.0003  0.0032  0.0162  0.0024
# 0208  0.2757  0.0046  0.2675  0.0043  0.2701  0.0044  0.2731  0.0054  0.0004  0.0032  0.0112  0.0017
# 0209  0.3045  0.0052  0.2949  0.0047  0.2973  0.0047  0.3021  0.0062  0.0002  0.0035  0.0121  0.0016
# 0210  0.3046  0.0052  0.2950  0.0047  0.2975  0.0047  0.3022  0.0062  0.0003  0.0035  0.0115  0.0018
# 0211  0.3363  0.0061  0.3247  0.0053  0.3271  0.0050  0.3339  0.0073  0.0002  0.0039  0.0124  0.0018
# 0212  0.3363  0.0061  0.3248  0.0053  0.3271  0.0051  0.3340  0.0073  0.0002  0.0039  0.0119  0.0020
# 0213  0.3635  0.0070  0.3498  0.0059  0.3521  0.0054  0.3612  0.0085  0.0003  0.0043  0.0126  0.0019
# 0214  0.3635  0.0070  0.3498  0.0060  0.3522  0.0054  0.3612  0.0085  0.0002  0.0043  0.0123  0.0021
# 0215  0.3905  0.0083  0.3741  0.0068  0.3766  0.0059  0.3880  0.0102  0.0002  0.0048  0.0129  0.0021
# 0216  0.3906  0.0083  0.3741  0.0068  0.3766  0.0059  0.3881  0.0102  0.0003  0.0048  0.0128  0.0022
# 0217  0.4046  0.0091  0.3864  0.0073  0.3891  0.0062  0.4019  0.0113  0.0003  0.0052  0.0130  0.0022
# 0218  0.4046  0.0091  0.3864  0.0073  0.3891  0.0062  0.4019  0.0112  0.0002  0.0052  0.0129  0.0022
# 0219  0.4190  0.0100  0.3989  0.0079  0.4019  0.0065  0.4161  0.0125  0.0003  0.0057  0.0132  0.0023
# 0220  0.4190  0.0100  0.3990  0.0080  0.4019  0.0065  0.4161  0.0126  0.0003  0.0057  0.0132  0.0023
# 0221  0.4264  0.0105  0.4052  0.0083  0.4082  0.0068  0.4233  0.0132  0.0004  0.0059  0.0132  0.0023
# 0222  0.4264  0.0106  0.4053  0.0084  0.4083  0.0068  0.4234  0.0132  0.0003  0.0060  0.0132  0.0023
# 0223  0.4246  0.0105  0.4034  0.0084  0.4065  0.0068  0.4215  0.0132  0.0004  0.0059  0.0131  0.0023
